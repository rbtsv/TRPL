# %%
# %load_ext memory_profiler 
# %memit

max1_tests_path = "./1-HelloWorld/1-2-max/tests"
cont_lis_path, cont_lis_tst = "../1-HelloWorld/cont_lis/", "t4"

def create_input(tests_path=max1_tests_path, test_num = "01"):
    test_file = open(f"{tests_path}/{test_num}", "r")
    return test_file.readline

input = create_input()

def read_int():
    return int(input())

def print_cf_style_input(tests_path=max1_tests_path, test_num = "01"):
    test_file = open(f"{tests_path}/{test_num}", "r")
    print("входные данные:")
    print(test_file.read())
    print("выходные данные:\n")

# %%
class InputIterator:
    def __init__(self, tests_path=max1_tests_path, test_num = "01"):
        self.input = create_input(tests_path, test_num)
        self.n = int(self.input())
        self.cur = 0
        
    def __iter__(self):        
        return self
    
    def __next__(self):
        if self.cur < self.n:
            self.cur += 1
            return(int(self.input()))
        raise StopIteration

# %% [markdown]
# # Рекурсия и итерация

# %%
iter_inp = InputIterator()

# %%
list(iter_inp)
# Out:
# [1, 3, 2, 7, 9, 4, 6, 5, 10, 8]

# %%
iter_inp = InputIterator()
m = next(iter_inp)
print(m)
m = next(iter_inp)
print(m)
m = next(iter_inp)
print(m)
print("----")
for x in iter_inp:
    print(m)
    m = max(m, x)
print("----")    
print(m)
# Out:
# 1
# 3
# 2
# ----
# 2
# 7
# 9
# 9
# 9
# 9
# 10
# ----
# 10

# %%
iter_inp = InputIterator()
for x in iter_inp:    
    m = max(m, x)
print(m)
# Out:
# 10

# %%
max(InputIterator())
# Out:
# 10

# %%
# %%time
m = 0
for x in range(10**7):
    m = max(m, x)
# Out:
# CPU times: user 1.15 s, sys: 27.3 ms, total: 1.18 s
# Wall time: 1.28 s

# %%
# %%time
m = 0
for x in range(10**7):
    m = m if m > x else x
# Out:
# CPU times: user 857 ms, sys: 18.9 ms, total: 876 ms
# Wall time: 914 ms

# %%
max([1,2,3]), max({1,5,3}), max((7,2,3))
# Out:
# (3, 5, 7)

# %%
iter_inp = InputIterator()
m = next(iter_inp)

for x in iter_inp:
    m = max(m, x)
    
print(m)
# Out:
# 10

# %%
func_iter = lambda m, x: max(m, x)

# %%
iter_inp = InputIterator()
m = next(iter_inp)

for x in iter_inp:
    m = func_iter(m, x)
    
print(m)
# Out:
# 10

# %%
from functools import reduce
reduce(func_iter, InputIterator(), -100000 )
# Out:
# 10

# %%
from functools import reduce
iter_inp = InputIterator()
acc = next(iter_inp)
result = reduce(func_iter, iter_inp, acc)
print(result)
# Out:
# 10

# %%
reduce(max, (iter_inp := InputIterator()), next(iter_inp))
# Out:
# 10

# %% [raw]
# f(x1, ... , xn) // f = max
# f(x1, x2)
# f(x1, x2, x3)
# f(x1, ... , xn) = F(f(x1, ... , x_{n-1}), xn)

# %%
def max_from_iterator(iterator, cur_max = 0):        
    try:        
        return max_from_iterator(iterator, max(cur_max, next(iterator)))
    except StopIteration:
        return cur_max

# %%
max_from_iterator(InputIterator())
# Out:
# 10

# %%
list(InputIterator())
# Out:
# [1, 3, 2, 7, 9, 4, 6, 5, 10, 8]

# %%
iter_inp = InputIterator()
m2, m1 = sorted([next(iter_inp), next(iter_inp)])
print(m1, m2)
# Out:
# 3 1

# %%
iter_inp = InputIterator()
m2, m1 = sorted([next(iter_inp), next(iter_inp)])
#print(m1, m2)
while True:
    try:        
        x = next(iter_inp)
        if x > m1:
            m1 = x # Неверный порядок действий!
            m2 = m1
        else: # x <= m1
            m2 = max(x, m2)
    except StopIteration:
        print(m1, m2)
        break
# Out:
# 10 10

# %%
iter_inp = InputIterator()
m2, m1 = sorted([next(iter_inp), next(iter_inp)])
#print(m1, m2)
while True:
    try:        
        x = next(iter_inp)
        if x > m1:
            m2 = m1
            m1 = x             
        else: # x <= m1
            m2 = max(x, m2)
    except StopIteration:
        print(m1, m2)
        break
# Out:
# 10 9

# %%
reduce(lambda acc, x: sorted([*acc, x])[1:], 
       (iter_inp := InputIterator()), 
       sorted([next(iter_inp), next(iter_inp)]))
# Out:
# [9, 10]

# %% [raw]
# f(x1, ... , xn) // f = max
# f(x1, x2)
# f(x1, x2, x3)
# f(x1, ... , xn) = F(f(x1, ... , x_{n-1}), xn)
# f(x1, ... , xn) = F(F(f(x1, ... , x_{n-2}), x_{n-1})), xn)
# f(x1, ... , xn) = F(F(F(f(x1, ... , x_{n-3}) x_{n-2}), x_{n-1})), xn)

# %%
def max_from_iterator(iterator, cur_max = 0):        
    try:        
        return max_from_iterator(iterator, max(cur_max, next(iterator)))
    except StopIteration:
        return cur_max

# %%
max_from_iterator(InputIterator(test_num = "09"))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 max_from_iterator(InputIterator(test_num = "09"))
#
# Cell In[30], line 3, in max_from_iterator(iterator, cur_max)
#       1 def max_from_iterator(iterator, cur_max = 0):
#       2     try:
# ----> 3         return max_from_iterator(iterator, max(cur_max, next(iterator)))
#       4     except StopIteration:
#       5         return cur_max
#
# Cell In[30], line 3, in max_from_iterator(iterator, cur_max)
#       1 def max_from_iterator(iterator, cur_max = 0):
#       2     try:
# ----> 3         return max_from_iterator(iterator, max(cur_max, next(iterator)))
#       4     except StopIteration:
#       5         return cur_max
#
#     [... skipping similar frames: max_from_iterator at line 3 (2975 times)]
#
# Cell In[30], line 3, in max_from_iterator(iterator, cur_max)
#       1 def max_from_iterator(iterator, cur_max = 0):
#       2     try:
# ----> 3         return max_from_iterator(iterator, max(cur_max, next(iterator)))
#       4     except StopIteration:
#       5         return cur_max
#
# RecursionError: maximum recursion depth exceeded

# %%
max(InputIterator(test_num = "09"))
# Out:
# 9999995

# %%
reduce(max, InputIterator(test_num = "09"))
# Out:
# 9999995

# %% [markdown]
# ## Числа Фибоначчи

# %%
def Fib(n):
    if n <= 2:
        return 1
    return Fib(n-1) + Fib(n-2)

# %%
[Fib(i) for i in range(1,10)]
# Out:
# [1, 1, 2, 3, 5, 8, 13, 21, 34]

# %%
def iter_Fib(n):
    a, b = 1, 1
    for i in range(n-2):
        a, b = a+b, a
    return a

# %%
[iter_Fib(i) for i in range(1,10)]
# Out:
# [1, 1, 2, 3, 5, 8, 13, 21, 34]

# %%
# %%time
Fib(40)
# Out:
# CPU times: user 9.43 s, sys: 144 ms, total: 9.57 s
# Wall time: 9.94 s
# 102334155

# %%
# %%time
iter_Fib(40)
# Out:
# CPU times: user 15 μs, sys: 0 ns, total: 15 μs
# Wall time: 20 μs
# 102334155

# %%
from functools import lru_cache

@lru_cache
def lru_Fib(n):
    if n <= 2:
       return 1
    return lru_Fib(n-1)+lru_Fib(n-2)

# %%
# %%time
lru_Fib(40)
# Out:
# CPU times: user 37 μs, sys: 50 μs, total: 87 μs
# Wall time: 96.1 μs
# 102334155

# %%
# %%time
lru_Fib(1000)
# Out:
# CPU times: user 660 μs, sys: 546 μs, total: 1.21 ms
# Wall time: 1.63 ms
# 43466557686937456435688527675040625802564660517371780402481729089536555417949051890403879840079255169295922593080322634775209689623239873322471161642996440906533187938298969649928516003704476137795166849228875

# %%
# %%time
iter_Fib(1000)
# Out:
# CPU times: user 109 μs, sys: 7 μs, total: 116 μs
# Wall time: 145 μs
# 43466557686937456435688527675040625802564660517371780402481729089536555417949051890403879840079255169295922593080322634775209689623239873322471161642996440906533187938298969649928516003704476137795166849228875

# %%
def Fib(n):          # 0
    if n <= 2:       
        r = 1
    else:        
        a = Fib(n-1) # 1
        b = Fib(n-2) # 2
        r = a + b    
    return r         # 3

# %%
def iter_stack_Fib(x):
    s = [(0, x, None, None, None)] # (line, n, a, b, r)
    while s:
        line, n, a, b, r = s.pop()
        if line == 3:
            result = r
        elif line == 0:
            if n <= 2:       
                # result = 1
                s.append((3, n, a, b, 1))
            else:
                s.append((1, n, a, b, r))
                s.append((0, n-1, None, None, None))
        elif line == 1:
            #b = Fib(n-2) # 2
            a = result
            s.append((2, n, a, b, r))
            s.append((0, n-2, None, None, None))
        elif line == 2:
            # r = a + b
            b = result 
            s.append((3, n, a, b, a+b))
    return result

# %%
[iter_stack_Fib(i) for i in range(1,10)]

# %%
# %%time
iter_stack_Fib(40)

# %%
# %%time
Fib(40)

# %%
def iter_stack_Fib(x):
    s = [(0, x, None, None)] # (line, n, a, b)
    while s:
       ...
    return result

# %%
[iter_stack_Fib(i) for i in range(1,10)]
